# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Collecting pytesseract
#   Downloading pytesseract-0.3.8.tar.gz (14 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from pytesseract) (7.1.2)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.8-py2.py3-none-any.whl size=14072 sha256=5bdbba7af1cca656c11e684312774f53a37a95bbcd3a6e8b9f989d41cc98313c
#   Stored in directory: /root/.cache/pip/wheels/a4/89/b9/3f11250225d0f90e5454fcc30fd1b7208db226850715aa9ace
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.8

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image
import matplotlib.pyplot as plt
import cv2

# %%
def read_from_img(path: str):
  return pytesseract.image_to_string(Image.open(path))

# %%
img = cv2.imread("1.png", cv2.IMREAD_COLOR)
img2 = cv2.imread("2.jpg", cv2.IMREAD_COLOR)
img3 = cv2.imread("3.jpg", cv2.IMREAD_COLOR)
img4 = cv2.imread("4.PNG", cv2.IMREAD_COLOR)
img5 = cv2.imread("5.jpg", cv2.IMREAD_COLOR)
img6 = cv2.imread("6.png", cv2.IMREAD_COLOR)

# %%
plt.imshow(img)
plt.show()

# %%
path = "1.png"
print(read_from_img(path))
# Out:
# Lorem
# ipsum

# %%
plt.imshow(img2)
plt.show()

# %%
path = "2.jpg"
print(read_from_img(path))

# %%
plt.imshow(img3)
plt.show()

# %%
path = "3.jpg"
print(read_from_img(path))
# Out:
# | [How To WRITE ALT |
#
# TEXT AND IMAGE
# DESCRIPTIONS FOR
# THE VISUALLY
# IMPAIRED

# %%
plt.imshow(img4)
plt.show()

# %%
path = "4.PNG"
print(read_from_img(path))
# Out:
# sii nder
#
# Aine es

# %%
plt.imshow(img5)
plt.show()

# %%
path = "5.jpg"
print(read_from_img(path))

# %%
plt.imshow(img6)
plt.show()

# %%
path = "6.png"
print(read_from_img(path))
# Out:
# HOW TO
# CHANGE TEXT COLOR
#
# IN PHOTOSHOP
